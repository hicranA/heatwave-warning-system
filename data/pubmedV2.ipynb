# %% [markdown]
# ## Acessing Pub Med data

# %% [markdown]
# First check to see if a library has a

# %% [markdown]
# Libraries

# %%
import requests
import pandas as pd

# %%
import requests
import pandas as pd

def search_pubmed(keyword):
    base_url = "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi"
    params = {
        "db": "pubmed",
        "term": keyword,
        "retmode": "json"
    }
    
    response = requests.get(base_url, params=params)
    data = response.json()
    pmids = data["esearchresult"]["idlist"]
    return pmids

def fetch_details(pmids):
    base_url = "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi"
    params = {
        "db": "pubmed",
        "id": ",".join(pmids),
        "retmode": "xml"
    }
    
    response = requests.get(base_url, params=params)
    return response.text

def extract_details_from_xml(xml_data):
    import xml.etree.ElementTree as ET
    root = ET.fromstring(xml_data)
    articles = []
    for article in root.findall(".//PubmedArticle"):
        title = article.find(".//ArticleTitle").text
        abstract = article.find(".//AbstractText")
        authors = article.findall(".//Author")
        author_list = []
        for author in authors:
            lastname = author.find("LastName")
            forename = author.find("ForeName")
            if lastname is not None and forename is not None:
                author_list.append(f"{forename.text} {lastname.text}")
        articles.append({
            "title": title,
            "abstract": abstract.text if abstract is not None else None,
            "authors": ", ".join(author_list)
        })
    return articles

# %%
import requests
import pandas as pd

def search_pubmed(keyword):
    base_url = "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi"
    params = {
        "db": "pubmed",
        "term": keyword,
        "retmode": "json"
    }
    
    response = requests.get(base_url, params=params)
    data = response.json()
    pmids = data["esearchresult"]["idlist"]
    return pmids

def fetch_details(pmids):
    base_url = "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi"
    params = {
        "db": "pubmed",
        "id": ",".join(pmids),
        "retmode": "xml"
    }
    
    response = requests.get(base_url, params=params)
    return response.text

def extract_details_from_xml(xml_data):
    import xml.etree.ElementTree as ET
    root = ET.fromstring(xml_data)
    articles = []
    for article in root.findall(".//PubmedArticle"):
        title = article.find(".//ArticleTitle").text
        abstract = article.find(".//AbstractText")
        authors = article.findall(".//Author")
        author_list = []
        for author in authors:
            lastname = author.find("LastName")
            forename = author.find("ForeName")
            if lastname is not None and forename is not None:
                author_list.append(f"{forename.text} {lastname.text}")
        articles.append({
            "title": title,
            "abstract": abstract.text if abstract is not None else None,
            "authors": ", ".join(author_list)
        })
    return articles

# Example usage:
countries = ["India", "USA", "Canada", "Australia", "Sri Lanka"]
df_data = []

for country in countries:
    print(country)
    keyword = f"(\"heatwave warning system\" OR \"heat health warning system\") AND \"{country}\""
    pmids = search_pubmed(keyword)
    if not pmids:  # If pmids is empty
        df_data.append({
            "country": country,
            "title": "Not found",
            "authors": "Not found",
            "abstract": "Not found"
        })
    else:
        xml_data = fetch_details(pmids)
        articles = extract_details_from_xml(xml_data)
        for article in articles:
            df_data.append({
                "country": country,
                "title": article["title"],
                "authors": article["authors"],
                "abstract": article["abstract"]
            })

df = pd.DataFrame(df_data)
print(df)

# %%
def search_pubmed(keyword):
    base_url = "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi"
    params = {
        "db": "pubmed",
        "term": keyword,
        "retmode": "json"
    }
    
    response = requests.get(base_url, params=params)
    
    if response.status_code == 200:
        data = response.json()
        pmids = data["esearchresult"]["idlist"]
        return pmids
    else:
        print(f"Error {response.status_code}: {response.text}")
        return []

# %%
keyword = "heat"  # Replace with your desired keyword
articles = search_pubmed(keyword)
print(f"Found {len(articles)} articles related to {keyword}.")
print("PMIDs:", articles)
# Out:
# Found 20 articles related to heat.
# PMIDs: ['37777598', '37777559', '37777526', '37777508', '37777396', '37777320', '37777316', '37777314', '37777034', '37776996', '37776751', '37776672', '37776620', '37776537', '37776525', '37776379', '37776281', '37776012', '37775950', '37775138']

# %%
import requests

def search_pubmed(keyword, max_results=10):
    base_url = "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi"
    params = {
        "db": "pubmed",
        "term": keyword,
        "retmode": "json",
        "retmax": max_results
    }
    
    response = requests.get(base_url, params=params)
    
    if response.status_code == 200:
        data = response.json()
        pmids = data["esearchresult"]["idlist"]
        return pmids
    else:
        print(f"Error {response.status_code}: {response.text}")
        return []

def fetch_details(pmids):
    base_url = "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi"
    params = {
        "db": "pubmed",
        "id": ",".join(pmids),
        "retmode": "xml"
    }
    
    response = requests.get(base_url, params=params)
    
    if response.status_code == 200:
        return response.text
    else:
        print(f"Error {response.status_code}: {response.text}")
        return ""

# Example usage:
keyword = "heat"  # Replace with your desired keyword
pmids = search_pubmed(keyword)
details = fetch_details(pmids)
print(details)
# Out:
# <?xml version="1.0" ?>
# <!DOCTYPE PubmedArticleSet PUBLIC "-//NLM//DTD PubMedArticle, 1st January 2023//EN" "https://dtd.nlm.nih.gov/ncbi/pubmed/out/pubmed_230101.dtd">
# <PubmedArticleSet>
# <PubmedArticle><MedlineCitation Status="Publisher" Owner="NLM" IndexingMethod="Automated"><PMID Version="1">37777598</PMID><DateRevised><Year>2023</Year><Month>09</Month><Day>30</Day></DateRevised><Article PubModel="Print-Electronic"><Journal><ISSN IssnType="Electronic">1433-8726</ISSN><JournalIssue CitedMedium="Internet"><PubDate><Year>2023</Year><Month>Sep</Month><Day>30</Day></PubDate></JournalIssue><Title>World journal of urology</Title><ISOAbbreviation>World J Urol</ISOAbbreviation></Journal><ArticleTitle>Change in renal blood flow in response to intrarenal pressure alterations induced by ureteroscopy in an in-vivo porcine model.</ArticleTitle><ELocationID EIdType="doi" ValidYN="Y">10.1007/s00345-023-04641-3</ELocationID><Abstract><AbstractText Label="INTRODUCTION" NlmCategory="BACKGROUND">High irrigation rates are commonly used during ureteroscopy and can increase intrarenal pressure (IRP) substantially. Concerns have been raised that elevated IRP may diminish renal blood flow (RBF) and perfusion of the kidney. Our objective was to investigate the real-time changes in RBF while increasing IRP during Ureteroscopy (URS) in an in-vivo porcine model.</AbstractText><AbstractText Label="METHODS" NlmCategory="METHODS">Four renal units in two porcine subjects were used in this study, three experimental units and one control. For the experimental units, RBF was measured by placing an ultrasonic flow cuff around the renal artery, while performing ureteroscopy in the same kidney using a prototype ureteroscope with a pressure sensor at its tip. Irrigation was cycled between two rates to achieve targeted IRPs of 30&#xa0;mmHg and 100&#xa0;mmHg. A control data set was obtained by placing the ultrasonic flow cuff on the contralateral renal artery while performing ipsilateral URS.</AbstractText><AbstractText Label="RESULTS" NlmCategory="RESULTS">At high IRP, RBF was reduced in all three experimental trials by 10-20% but not in the control trial. The percentage change in RBF due to alteration in IRP was internally consistent in each porcine renal unit and independent of slower systemic variation in RBF encountered in both the experimental and control units.</AbstractText><AbstractText Label="CONCLUSION" NlmCategory="CONCLUSIONS">RBF decreased 10-20% when IRP was increased from 30 to 100&#xa0;mmHg during ureteroscopy in an in-vivo porcine model. While this reduction in RBF is unlikely to have an appreciable effect on tissue oxygenation, it may impact heat-sink capacity in vulnerable regions of the kidney.</AbstractText><CopyrightInformation>&#xa9; 2023. This is a U.S. Government work and not under copyright protection in the US; foreign copyright protection may apply.</CopyrightInformation></Abstract><AuthorList CompleteYN="Y"><Author ValidYN="Y"><LastName>Marom</LastName><ForeName>Ron</ForeName><Initials>R</Initials><Identifier Source="ORCID">0000-0003-2137-1057</Identifier><AffiliationInfo><Affiliation>Department of Urology, University of Michigan, 4432 Medical Science I, 1301 Catherine Street, Ann Arbor, MI, 48109-5330, USA. ronmarom@gmail.com.</Affiliation></AffiliationInfo></Author><Author ValidYN="Y"><LastName>Dau</LastName><ForeName>Julie J</ForeName><Initials>JJ</Initials><AffiliationInfo><Affiliation>Department of Urology, University of Michigan, 4432 Medical Science I, 1301 Catherine Street, Ann Arbor, MI, 48109-5330, USA.</Affiliation></AffiliationInfo></Author><Author ValidYN="Y"><LastName>Ghani</LastName><ForeName>Khurshid R</ForeName><Initials>KR</Initials><AffiliationInfo><Affiliation>Department of Urology, University of Michigan, 4432 Medical Science I, 1301 Catherine Street, Ann Arbor, MI, 48109-5330, USA.</Affiliation></AffiliationInfo></Author><Author ValidYN="Y"><LastName>Hall</LastName><ForeName>Timothy L</ForeName><Initials>TL</Initials><AffiliationInfo><Affiliation>Department of Biomedical Engineering, University of Michigan, Ann Arbor, MI, USA.</Affiliation></AffiliationInfo></Author><Author ValidYN="Y"><LastName>Ro ...

# %%
import pickle

# %%
country_list = pickle.load(open("arrays.pkl", "rb"))
country_list
# Out:
# [['Papua New Guinea',
#   'Singapore',
#   'Sao Tome and Principe',
#   'Czechia',
#   'Djibouti',
#   'Sri Lanka',
#   'Burkina Faso',
#   'Brunei Darussalam',
#   'British Caribbean Territories - Montserrat'],
#  ['Nicaragua',
#   'Brazil',
#   'Kuwait',
#   'Ireland',
#   'Poland',
#   'Pakistan',
#   'Bolivia (Plurinational State of)',
#   'North Macedonia',
#   'Tuvalu'],
#  ['Morocco',
#   'Kiribati',
#   'Seychelles',
#   'Uzbekistan',
#   'Egypt',
#   'Curaçao and Sint Maarten',
#   "Democratic People's Republic of Korea",
#   'Chad',
#   'Azerbaijan'],
#  ['Chile',
#   'Zambia',
#   'British Caribbean Territories - Anguilla',
#   'Latvia',
#   'Panama',
#   'Ukraine',
#   'Macao, China',
#   'Antigua and Barbuda',
#   'Saint Lucia'],
#  ['Cameroon',
#   'Croatia',
#   'Hong Kong, China',
#   'British Caribbean Territories',
#   'Malta',
#   'Kazakhstan',
#   'United States of America',
#   'Norway',
#   'Madagascar'],
#  ['Georgia',
#   'Thailand',
#   'Cambodia',
#   'Guyana',
#   'Afghanistan',
#   'Bangladesh',
#   'Iraq',
#   'Slovakia',
#   'Costa Rica'],
#  ['Ghana',
#   'Algeria',
#   "Côte d'Ivoire",
#   'United Arab Emirates',
#   'Albania',
#   'Tajikistan',
#   'Mongolia',
#   'Eritrea',
#   "Lao People's Democratic Republic"],
#  ['Micronesia (Federated States of)',
#   'Malawi',
#   'Monaco',
#   'Bhutan',
#   'Canada',
#   'Burundi',
#   'Hungary',
#   'United Republic of Tanzania',
#   'Nauru'],
#  ['Greece',
#   'Germany',
#   'Colombia',
#   'France',
#   'Andorra',
#   'Austria',
#   'Cyprus',
#   'Finland',
#   'Jordan'],
#  ['Comoros',
#   'Maldives',
#   'Togo',
#   'Luxembourg',
#   'Bosnia and Herzegovina',
#   'Central African Republic',
#   'Myanmar',
#   'Cabo Verde',
#   'Bahamas'],
#  ['Suriname',
#   'Argentina',
#   'French Polynesia',
#   'Peru',
#   'Kenya',
#   'Sierra Leone',
#   'Mozambique',
#   'British Caribbean Territories - British Virgin Islands',
#   'Republic of Moldova'],
#  ['Ecuador',
#   'Turkmenistan',
#   'Mexico',
#   'Uganda',
#   'British Caribbean Territories - Cayman Islands',
#   'Tonga',
#   'Niue',
#   'Venezuela, Bolivarian Republic of',
#   'Saudi Arabia'],
#  ['Solomon Islands',
#   'Dominica',
#   'Gambia (The)',
#   'Italy',
#   'Zimbabwe',
#   'Fiji',
#   'New Zealand',
#   'El Salvador',
#   'Malaysia'],
#  ['Liberia',
#   'Niger',
#   'Mali',
#   'Japan',
#   'Lebanon',
#   'Indonesia',
#   'Jamaica',
#   'Democratic Republic of the Congo',
#   'Viet Nam'],
#  ['Vanuatu',
#   'Montenegro',
#   'Guinea',
#   'Mauritania',
#   'Dominican Republic',
#   'Honduras',
#   'Lithuania',
#   'Eswatini',
#   'Israel'],
#  ['Cuba',
#   'Ethiopia',
#   'Lesotho',
#   'Iceland',
#   'Australia',
#   'Gabon',
#   'Haiti',
#   'Nigeria',
#   'Portugal'],
#  ['Romania',
#   'Senegal',
#   'Sudan',
#   'Timor-Leste',
#   'Botswana',
#   'New Caledonia',
#   'British Caribbean Territories - Turks and Caicos Islands',
#   'Uruguay',
#   'Samoa'],
#  ['Nepal',
#   'Denmark',
#   'Barbados',
#   'Belize',
#   'Namibia',
#   'Qatar',
#   'Rwanda',
#   'Serbia',
#   'South Africa'],
#  ['Yemen',
#   'Mauritius',
#   'Cook Islands',
#   'Guinea-Bissau',
#   'Belarus',
#   'Slovenia',
#   'China',
#   'India',
#   'Türkiye'],
#  ['Tunisia',
#   'Somalia',
#   'Benin',
#   'Oman',
#   'Switzerland',
#   'Russian Federation',
#   'Congo',
#   'Iran (Islamic Republic of)',
#   'Trinidad and Tobago'],
#  ['Syrian Arab Republic',
#   'Angola',
#   'Paraguay',
#   'Sweden',
#   'Spain',
#   'Guatemala',
#   'Armenia',
#   'Belgium',
#   'South Sudan'],
#  ['Netherlands',
#   'Estonia',
#   'Philippines',
#   'Bulgaria',
#   'Kyrgyzstan',
#   'United Kingdom of Great Britain and Northern Ireland',
#   'Republic of Korea',
#   'Libya (State of)',
#   'Bahrain']]

# %%
len(country_list)
# Out:
# 22

# %%
import requests
import xml.etree.ElementTree as ET

def search_pubmed(keyword, max_results=10):
    base_url = "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi"
    params = {
        "db": "pubmed",
        "term": keyword,
        "retmode": "json",
        "retmax": max_results
    }
    
    response = requests.get(base_url, params=params)
    
    if response.status_code == 200:
        data = response.json()
        pmids = data["esearchresult"]["idlist"]
        return pmids
    else:
        print(f"Error {response.status_code}: {response.text}")
        return []

def fetch_details(pmids):
    base_url = "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi"
    params = {
        "db": "pubmed",
        "id": ",".join(pmids),
        "retmode": "xml"
    }
    
    response = requests.get(base_url, params=params)
    
    if response.status_code == 200:
        return response.text
    else:
        print(f"Error {response.status_code}: {response.text}")
        return ""

def parse_and_print_details(xml_data):
    root = ET.fromstring(xml_data)
    for article in root.findall(".//PubmedArticle"):
        title = article.find(".//ArticleTitle").text
        abstract = article.find(".//AbstractText")
        authors = article.findall(".//Author")
        
        print("Title:", title)
        if abstract is not None:
            print("Abstract:", abstract.text)
        print("Authors:")
        for author in authors:
            lastname = author.find("LastName")
            forename = author.find("ForeName")
            if lastname is not None and forename is not None:
                print(f"  {forename.text} {lastname.text}")
        print("="*80)

# Example usage:
keyword = "Turkey heatwave warning system" 
pmids = search_pubmed(keyword)
details = fetch_details(pmids)
parse_and_print_details(details)
# Out:
# Title: The unprecedented 2022 extreme summer heatwaves increased harmful cyanobacteria blooms.
# Abstract: Heatwaves are increasing and expected to intensify in coming decades with global warming. However, direct evidence and knowledge of the mechanisms of the effects of heatwaves on harmful cyanobacteria blooms are limited and unclear. In 2022, we measured chlorophyll-a (Chla) at 20-s intervals based on a novel ground-based proximal sensing system (GBPSs) in the shallow eutrophic Lake Taihu and combined in situ Chla measurements with meteorological data to explore the impacts of heatwaves on cyanobacterial blooms and the potential relevant mechanisms. We found that three unprecedented summer heatwaves (July 4-15, July 22-August 16, and August 18-23) lasting a total of 44 days were observed with average maximum air temperatures (MATs) of 38.1 ± 1.9 °C, 38.7 ± 1.9 °C, and 40.2 ± 2.1 °C, respectively, and that these heatwaves were characterized by high air temperature, strong PAR, low wind speed and rainfall. The daily Chla significantly increased with increasing MAT and photosynthetically active radiation (PAR) and decreasing wind speed, revealing a clear promotion effect on harmful cyanobacteria blooms from the heatwaves. Moreover, the combined effects of high temperature, strong PAR and low wind, enhanced the stability of the water column, the light availability and the phosphorus release from the sediment which ultimately boosted cyanobacteria blooms. The projected increase in heatwave occurrence under future climate change underscores the urgency of reducing nutrient input to eutrophic lakes to combat cyanobacteria growth and of improving early warning systems to ensure secure water management.
# Authors:
#   Na Li
#   Yunlin Zhang
#   Yibo Zhang
#   Kun Shi
#   Haiming Qian
#   Huayin Yang
#   Yongkang Niu
#   Boqiang Qin
#   Guangwei Zhu
#   R Iestyn Woolway
#   Erik Jeppesen
# ================================================================================

# %%
import requests
import xml.etree.ElementTree as ET

def search_pubmed(keyword, max_results=10):
    base_url = "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi"
    params = {
        "db": "pubmed",
        "term": keyword,
        "retmode": "json",
        "retmax": max_results
    }
    
    response = requests.get(base_url, params=params)
    
    if response.status_code == 200:
        data = response.json()
        pmids = data["esearchresult"]["idlist"]
        return pmids
    else:
        print(f"Error {response.status_code}: {response.text}")
        return []

def fetch_details(pmids):
    base_url = "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi"
    params = {
        "db": "pubmed",
        "id": ",".join(pmids),
        "retmode": "xml"
    }
    
    response = requests.get(base_url, params=params)
    
    if response.status_code == 200:
        return response.text
    else:
        print(f"Error {response.status_code}: {response.text}")
        return ""

def parse_and_print_details(xml_data):
    root = ET.fromstring(xml_data)
    for article in root.findall(".//PubmedArticle"):
        title = article.find(".//ArticleTitle").text
        abstract = article.find(".//AbstractText")
        authors = article.findall(".//Author")
        
        print("Title:", title)
        if abstract is not None:
            print("Abstract:", abstract.text)
        print("Authors:")
        for author in authors:
            lastname = author.find("LastName")
            forename = author.find("ForeName")
            if lastname is not None and forename is not None:
                print(f"  {forename.text} {lastname.text}")
        print("="*80)

# Example usage:
keyword = "heatwave AND warning AND system AND Turkey" 
pmids = search_pubmed(keyword)
details = fetch_details(pmids)
parse_and_print_details(details)
# Out:
# Title: The unprecedented 2022 extreme summer heatwaves increased harmful cyanobacteria blooms.
# Abstract: Heatwaves are increasing and expected to intensify in coming decades with global warming. However, direct evidence and knowledge of the mechanisms of the effects of heatwaves on harmful cyanobacteria blooms are limited and unclear. In 2022, we measured chlorophyll-a (Chla) at 20-s intervals based on a novel ground-based proximal sensing system (GBPSs) in the shallow eutrophic Lake Taihu and combined in situ Chla measurements with meteorological data to explore the impacts of heatwaves on cyanobacterial blooms and the potential relevant mechanisms. We found that three unprecedented summer heatwaves (July 4-15, July 22-August 16, and August 18-23) lasting a total of 44 days were observed with average maximum air temperatures (MATs) of 38.1 ± 1.9 °C, 38.7 ± 1.9 °C, and 40.2 ± 2.1 °C, respectively, and that these heatwaves were characterized by high air temperature, strong PAR, low wind speed and rainfall. The daily Chla significantly increased with increasing MAT and photosynthetically active radiation (PAR) and decreasing wind speed, revealing a clear promotion effect on harmful cyanobacteria blooms from the heatwaves. Moreover, the combined effects of high temperature, strong PAR and low wind, enhanced the stability of the water column, the light availability and the phosphorus release from the sediment which ultimately boosted cyanobacteria blooms. The projected increase in heatwave occurrence under future climate change underscores the urgency of reducing nutrient input to eutrophic lakes to combat cyanobacteria growth and of improving early warning systems to ensure secure water management.
# Authors:
#   Na Li
#   Yunlin Zhang
#   Yibo Zhang
#   Kun Shi
#   Haiming Qian
#   Huayin Yang
#   Yongkang Niu
#   Boqiang Qin
#   Guangwei Zhu
#   R Iestyn Woolway
#   Erik Jeppesen
# ================================================================================

# %% [markdown]
# we can create an x list shows the results

# %%
testList = ["Germany", "Italy", "Spain"]

for country in testList:
    print(country)
    keyword = f"heatwave warning AND system AND {country}" 
    pmids = search_pubmed(keyword)
    details = fetch_details(pmids)
    parse_and_print_details(details)
    print("="*80)
# Out:
# Germany
# Title: Physical Activity, Climate Change and Health-A Conceptual Model for Planning Public Health Action at the Organizational Level.
# Abstract: Climate change is linked to health risks for both professional and amateur athletes. Sports organisations will need to react to these developments. The starting point for this concept paper is a summary of the sport-specific health risks currently under discussion: increasing heatwaves, growing numbers of extreme weather events, rising UV, ozone and allergen levels and the spread of infectious diseases. Based on the current state of research, a conceptual model is developed to reduce these climate-related health risks in sports at organisational level. Given the wide variety of predicted direct and indirect health risks linked to climate change, the "sports, clubs and climate change model" (SC
# Authors:
#   Sven Schneider
#   Alexandra von Winning
#   Fiona Grüger
#   Stefan Anderer
#   Robert Hoffner
#   Lilian Anderson
# ================================================================================
# Title: Governing heatwaves in Europe: comparing health policy and practices to better understand roles, responsibilities and collaboration.
# Abstract: The expectation that climate change will further exacerbate extreme weather events such as heatwaves is of primary concern to policymakers and scientists. Effective governance is fundamental to preparedness for and response to such threats. This paper explores the governance structures of European heat health action plans and provides insights into key stakeholders, roles, responsibilities and collaboration.
# Authors:
#   Kirsten Vanderplanken
#   Peter van den Hazel
#   Michael Marx
#   Ahmad Zia Shams
#   Debarati Guha-Sapir
#   Joris Adriaan Frank van Loenhout
# ================================================================================
# Title: [Heat-related morbidity: real-time surveillance via rescue service operations data from the interdisciplinary care capacity proof system (IVENA)].
# Abstract: In addition to mortality data, hospital admission, emergency department visits, and emergency service calls data are used for the surveillance of heat-related morbidity. We report on heat-associated morbidity in Frankfurt am Main from 2014-2018 using the web-based care capacity proof system (IVENA) of the rescue service operations.
# Authors:
#   Katrin Steul
#   Hans-Georg Jung
#   Ursel Heudorf
# ================================================================================
# ================================================================================
# Italy
# Title: Prevention and management of health hazards related to heatwaves.
# Abstract: The general aim of the EuroHEAT project was to improve public health responses to weather extremes and, in particular, to heatwaves.
# Authors:
#   Franziska Matthies
#   Bettina Menne
# ================================================================================
# Title: [Risk factors for mortality during a heat-wave in Bari (Italy), summer 2005.].
# Abstract: The Italian Heat Health Watch Warning System (HHWWS) was set up following the over 3000 excess deaths which occurred in Italy during the heat wave of 2003, In June 2005 the warning system issued a heat warning in various Italian cities.
# Authors:
#   Bruno Christian Ciancio
#   Massimiliano Di Renzi
#   Nancy Binkin
#   Alberto Perra
#   Rosa Prato
#   Antonino Bella
#   Paolo Niutta
#   Fabrizio Rossi
#   Cinzia Germinario
#   Maria Teresa Balducci
#   Giovanni Caputi
#   Annarita Fusco
# ================================================================================
# ================================================================================
# Spain
# Title: Explorative Assessment of the Temperature-Mortality Association to Support Health-Based Heat-Warning Thresholds: A National Case-Crossover Study in Switzerland.
# Abstract: Defining health-based thresholds for effective heat warnings is crucial for climate change adaptation strategies. Translating the non-linear function between heat and health effects into an effective threshold for heat warnings to protect the population is a challenge. We present a systematic analysis of heat indicators in relation to mortality. We applied distributed lag non-linear models in an individual-level case-crossover design to assess the effects of heat on mortality in Switzerland during the warm season from 2003 to 2016 for three temperature metrics (daily mean, maximum, and minimum temperature), and various threshold temperatures and heatwave definitions. Individual death records with information on residential address from the Swiss National Cohort were linked to high-resolution temperature estimates from 100 m resolution maps. Moderate (90th percentile) to extreme thresholds (99.5th percentile) of the three temperature metrics implied a significant increase in mortality (5 to 38%) in respect of the median warm-season temperature. Effects of the threshold temperatures on mortality were similar across the seven major regions in Switzerland. Heatwave duration did not modify the effect when considering delayed effects up to 7 days. This nationally representative study, accounting for small-scale exposure variability, suggests that the national heat-warning system should focus on heatwave intensity rather than duration. While a different heat-warning indicator may be appropriate in other countries, our evaluation framework is transferable to any country.
# Authors:
#   Martina S Ragettli
#   Apolline Saucy
#   Benjamin Flückiger
#   Danielle Vienneau
#   Kees de Hoogh
#   Ana M Vicedo-Cabrera
#   Christian Schindler
#   Martin Röösli
# ================================================================================
# ================================================================================

# %%
import requests

def search_pubmed_for_country(country):
    base_url = "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi"
    queries = [
        f"\"heatwave warning system\" AND \"{country}\"",
        f"\"heat health warning system\" AND \"{country}\""
    ]
    
    for query in queries:
        params = {
            "db": "pubmed",
            "term": query,
            "retmode": "json"
        }
        
        response = requests.get(base_url, params=params)
        data = response.json()
        article_count = int(data["esearchresult"]["count"])
        
        if article_count > 0:
            return True  # Found articles related to the query for the country
    
    return False  # No articles found for any of the queries for the country

countries = ["India", "USA", "Canada", "Australia"]
results = {}

for country in countries:
    has_system = search_pubmed_for_country(country)
    results[country] = "Has system" if has_system else "No system found"

print(results)
# Out:
# {'India': 'Has system', 'USA': 'Has system', 'Canada': 'Has system', 'Australia': 'Has system'}

# %%
import requests
import pandas as pd

def search_pubmed(keyword):
    base_url = "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/esearch.fcgi"
    params = {
        "db": "pubmed",
        "term": keyword,
        "retmode": "json"
    }
    
    response = requests.get(base_url, params=params)
    data = response.json()
    pmids = data["esearchresult"]["idlist"]
    return pmids

def fetch_details(pmids):
    base_url = "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi"
    params = {
        "db": "pubmed",
        "id": ",".join(pmids),
        "retmode": "xml"
    }
    
    response = requests.get(base_url, params=params)
    return response.text

def extract_details_from_xml(xml_data):
    import xml.etree.ElementTree as ET
    root = ET.fromstring(xml_data)
    articles = []
    for article in root.findall(".//PubmedArticle"):
        title = article.find(".//ArticleTitle").text
        abstract = article.find(".//AbstractText")
        authors = article.findall(".//Author")
        author_list = []
        for author in authors:
            lastname = author.find("LastName")
            forename = author.find("ForeName")
            if lastname is not None and forename is not None:
                author_list.append(f"{forename.text} {lastname.text}")
        articles.append({
            "title": title,
            "abstract": abstract.text if abstract is not None else None,
            "authors": ", ".join(author_list)
        })
    return articles

# Example usage:
countries = ["India", "USA", "Canada", "Australia", "Sri Lanka"]
df_data = []

for country in countries:
    print(country)
    keyword = f"(\"heatwave warning system\" OR \"heat health warning system\") AND \"{country}\""
    pmids = search_pubmed(keyword)
    if not pmids:  # If pmids is empty
        df_data.append({
            "country": country,
            "title": "Not found",
            "authors": "Not found",
            "abstract": "Not found"
        })
    else:
        xml_data = fetch_details(pmids)
        articles = extract_details_from_xml(xml_data)
        for article in articles:
            df_data.append({
                "country": country,
                "title": article["title"],
                "authors": article["authors"],
                "abstract": article["abstract"]
            })

df = pd.DataFrame(df_data)
print(df)
# Out:
# India
# USA
# Canada
# Australia
# Sri Lanka
#       country                                              title  \
# 0       India  Projected climate extremes over agro-climatic ...
# 1         USA  Extreme Heat and Adverse Cardiovascular Outcom...
# 2         USA  Examining the joint effects of heatwaves, air ...
# 3         USA  Characterization of heat index experienced by ...
# 4         USA  Abrupt shift to hotter and drier climate over ...
# 5         USA  Performance of heat-health warning systems in ...
# 6         USA  The warm summer of 2018 - increased mortality ...
# 7         USA  Effects of heat waves on daily excess mortalit...
# 8         USA  Effect Modification by Environmental Quality o...
# 9         USA  Heat stroke internet searches can be a new hea...
# 10        USA  Excess seawater nutrients, enlarged algal symb...
# 11     Canada  Mortality Risk Related to Heatwaves in Dezful ...
# 12     Canada  Extreme Heat and Adverse Cardiovascular Outcom...
# 13     Canada  Cardiovascular Health Peaks and Meteorological...
# 14     Canada  Heat-health warning systems: a comparison of t...
# 15  Australia  The Scorching Truth: Investigating the Impact ...
# 16  Australia  Extreme Heat and Adverse Cardiovascular Outcom...
# 17  Australia  Evaluation of climate change adaptation measur...
# 18  Australia  Evaluating cost benefits from a heat health wa...
# 19  Australia  The association between heatwaves and risk of ...
# 20  Australia  Performance of Excess Heat Factor Severity as ...
# 21  Australia  Heatwave and elderly mortality: An evaluation ...
# 22  Australia  Heatwave and health events: A systematic evalu...
# 23  Australia  Heatwave and infants' hospital admissions unde...
# 24  Australia  Excess seawater nutrients, enlarged algal symb...
# 25  Australia  Evaluation of a heat warning system in Adelaid...
# 26  Australia  Impact of heatwave on mortality under differen...
# 27  Australia  The Impacts of Heatwaves on Mortality Differ w...
# 28  Australia  Development of health risk-based metrics for d...
# 29  Australia  Evaluating the effectiveness of heat warning s...
# 30  Australia                Are heat warning systems effective?
# 31  Australia  The effects of summer temperature, age and soc...
# 32  Sri Lanka                                          Not found
#
#                                               authors  \
# 0   Harsh Vardhan Singh, Nitin Joshi, Shakti Surya...
# 1   Georgia K Chaseling, Nathan B Morris, Nicholas...
# 2   Yi Sun, Sindana D Ilango, Lara Schwarz, Qiong ...
# 3   Suwei Wang, Connor Y H Wu, Molly B Richardson,...
# 4   Peng Zhang, Jee-Hoon Jeong, Jin-Ho Yoon, Hyung...
# 5   Yaqiao Wu, Xiaoye Wang, Jingyan Wu, Rui Wang, ...
# 6   Anette Hylen Ranhoff, Hans Olav Hygen, Frances...
# 7   Dae-Geun Lee, Kyu Rang Kim, Jiyoung Kim, Baek-...
# 8             Yun Jian, Connor Y H Wu, Julia M Gohlke
# 9   Tiantian Li, Fan Ding, Qinghua Sun, Yi Zhang, ...
# 10  Scott A Wooldridge, Scott F Heron, Jon E Brodi...
# 11  Hamidreza Aghababaeian, Abbas Ostadtaghizadeh,...
# 12  Georgia K Chaseling, Nathan B Morris, Nicholas...
# 13  Yohann Moanahere Chiu, Fateh Chebana, Belkacem...
# 14  Shakoor Hajat, Scott C Sheridan, Michael J All...
# 15  Kun Hing Yong, Yen Nee Teo, Mohsen Azadbakht, ...
# 16  Georgia K Chaseling, Nathan B Morris, Nicholas...
# 17  Yabin Hu, Jian Cheng, Shijian Liu, Jianguo Tan...
# 18  Susan Williams, Monika Nitschke, Berhanu Yazew...
# 19  Qi Zhao, Shanshan Li, Micheline S Z S Coelho, ...
# 20             John Nairn, Bertram Ostendorf, Peng Bi
# 21  Jian Cheng, Zhiwei Xu, Hilary Bambrick, Hong S...
# 22      Zhiwei Xu, Jian Cheng, Wenbiao Hu, Shilu Tong
# 23  Zhiwei Xu, James Lewis Crooks, Deborah Black, ...
# 24  Scott A Wooldridge, Scott F Heron, Jon E Brodi...
# 25  Monika Nitschke, Graeme Tucker, Alana Hansen, ...
# 26  Zhiwei Xu, Gerard FitzGerald, Yuming Guo, Bin ...
# 27  Xiao Yu Wang, Yuming Guo, Gerry FitzGerald, Pe...
# 28  Shilu Tong, Xiao Yu Wang, Gerry FitzGerald, Da...
# 29  Ghasem Toloo, Gerard FitzGerald, Peter Aitken,...
# 30  Ghasem Sam Toloo, Gerard Fitzgerald, Peter Ait...
# 31  Margaret E Loughnan, Neville Nicholls, Nigel J...
# 32                                          Not found
#
#                                              abstract
# 0   Recurring floods, droughts, heatwaves, and oth...
# 1   Extreme heat events are a leading natural haza...
# 2   Exposure to high air temperature in late pregn...
# 3   Heatwave warning systems rely on forecasts mad...
# 4   Unprecedented heatwave-drought concurrences in...
# 5   In response to more frequent heatwaves, variou...
# 6   Heatwaves in Europe and the USA have been show...
# 7   The aims of this study are to explore the "off...
# 8                                                None
# 9   The impact of major heatwave shocks on populat...
# 10  A spatial risk assessment model is developed f...
# 11  We aimed to evaluate the impact of heatwaves o...
# 12  Extreme heat events are a leading natural haza...
# 13  Cardiovascular morbidity and mortality are inf...
# 14  We compared the ability of several heat-health...
# 15  Global climate change has contributed to the i...
# 16  Extreme heat events are a leading natural haza...
# 17  Global climate change (GCC) is widely accepted...
# 18  To examine the cost benefits of a heat health ...
# 19  To our knowledge, no study has assessed the as...
# 20  The establishment of an effective policy respo...
# 21  A heatwave can be a devastating natural disast...
# 22  Temperature observation time and type influenc...
# 23  Data on the health impacts of heatwaves in inf...
# 24  A spatial risk assessment model is developed f...
# 25  Heatwave warning systems aim to assist in redu...
# 26  Heatwave effects on human health and wellbeing...
# 27  Different locations and study periods were use...
# 28  This study attempted to develop health risk-ba...
# 29  To review the existing research on the effecti...
# 30  Heatwaves are associated with significant heal...
# 31  Published literature detailing the effects of ...
# 32                                          Not found

# %%
countries = country_list[0]
df_data = []

for country in countries:
    print(country)
    keyword = f"(\"heatwave warning system\" OR \"heat health warning system\") AND \"{country}\""
    pmids = search_pubmed(keyword)
    if not pmids:  # If pmids is empty
        df_data.append({
            "country": country,
            "title": "Not found",
            "authors": "Not found",
            "abstract": "Not found"
        })
    else:
        xml_data = fetch_details(pmids)
        articles = extract_details_from_xml(xml_data)
        for article in articles:
            df_data.append({
                "country": country,
                "title": article["title"],
                "authors": article["authors"],
                "abstract": article["abstract"]
            })

df = pd.DataFrame(df_data)
print(df)
# Out:
# Papua New Guinea
# Singapore
# Sao Tome and Principe
# Czechia
# Djibouti
# Sri Lanka
# Burkina Faso
# Brunei Darussalam
# British Caribbean Territories - Montserrat
#                                       country      title    authors   abstract
# 0                            Papua New Guinea  Not found  Not found  Not found
# 1                                   Singapore  Not found  Not found  Not found
# 2                       Sao Tome and Principe  Not found  Not found  Not found
# 3                                     Czechia  Not found  Not found  Not found
# 4                                    Djibouti  Not found  Not found  Not found
# 5                                   Sri Lanka  Not found  Not found  Not found
# 6                                Burkina Faso  Not found  Not found  Not found
# 7                           Brunei Darussalam  Not found  Not found  Not found
# 8  British Caribbean Territories - Montserrat  Not found  Not found  Not found

# %%
countries = country_list[1]
df_data = []

for country in countries:
    print(country)
    keyword = f"(\"heatwave warning system\" OR \"heat health warning system\") AND \"{country}\""
    pmids = search_pubmed(keyword)
    if not pmids:  # If pmids is empty
        df_data.append({
            "country": country,
            "title": "Not found",
            "authors": "Not found",
            "abstract": "Not found"
        })
    else:
        xml_data = fetch_details(pmids)
        articles = extract_details_from_xml(xml_data)
        for article in articles:
            df_data.append({
                "country": country,
                "title": article["title"],
                "authors": article["authors"],
                "abstract": article["abstract"]
            })

df2 = pd.DataFrame(df_data)
print(df)
# Out:
# Nicaragua
# Brazil
# Kuwait
# Ireland
# Poland
# Pakistan
# Bolivia (Plurinational State of)
# North Macedonia
# Tuvalu
#                                       country      title    authors   abstract
# 0                            Papua New Guinea  Not found  Not found  Not found
# 1                                   Singapore  Not found  Not found  Not found
# 2                       Sao Tome and Principe  Not found  Not found  Not found
# 3                                     Czechia  Not found  Not found  Not found
# 4                                    Djibouti  Not found  Not found  Not found
# 5                                   Sri Lanka  Not found  Not found  Not found
# 6                                Burkina Faso  Not found  Not found  Not found
# 7                           Brunei Darussalam  Not found  Not found  Not found
# 8  British Caribbean Territories - Montserrat  Not found  Not found  Not found

# %%
df_collector = pd.DataFrame()

for list in country_list:
    df_data = []
    for country in list:
        print(country)
        keyword = f"(\"heatwave warning system\" OR \"heat health warning system\") AND \"{country}\""
        pmids = search_pubmed(keyword)
        if not pmids:  # If pmids is empty
            df_data.append({
                "country": country,
                "title": "Not found",
                "authors": "Not found",
                "abstract": "Not found"
            })
        else:
            xml_data = fetch_details(pmids)
            articles = extract_details_from_xml(xml_data)
            for article in articles:
                df_data.append({
                    "country": country,
                    "title": article["title"],
                    "authors": article["authors"],
                    "abstract": article["abstract"]
                })
        df = pd.DataFrame(df_data)
        df_collector = df_collector.append(df, ignore_index=True)
    
print(df_collector)

# %%
import requests
import pandas as pd

# ... [rest of the functions]

df_collector = pd.DataFrame()

for list in country_list:
    df_data = []
    for country in list:
        print(country)
        keyword = f"(\"heatwave warning system\" OR \"heat health warning system\") AND \"{country}\""
        pmids = search_pubmed(keyword)
        if not pmids:  # If pmids is empty
            df_data.append({
                "country": country,
                "title": "Not found",
                "authors": "Not found",
                "abstract": "Not found"
            })
        else:
            xml_data = fetch_details(pmids)
            articles = extract_details_from_xml(xml_data)
            for article in articles:
                df_data.append({
                    "country": country,
                    "title": article["title"],
                    "authors": article["authors"],
                    "abstract": article["abstract"]
                })
        df = pd.DataFrame(df_data)
        df_collector = pd.concat([df_collector, df], ignore_index=True)
    
print(df_collector)
# Out:
# Papua New Guinea
# Singapore
# Sao Tome and Principe
# Czechia
# Djibouti
# Sri Lanka
# Burkina Faso
# Brunei Darussalam
# British Caribbean Territories - Montserrat
# Nicaragua
# Brazil
# Kuwait
# Ireland
# Poland
# Pakistan
# Bolivia (Plurinational State of)
# North Macedonia
# Tuvalu
# Morocco
# Kiribati
# Seychelles
# Uzbekistan
# Egypt
# Curaçao and Sint Maarten
# Democratic People's Republic of Korea
# Chad
# Azerbaijan
# Chile
# Zambia
# British Caribbean Territories - Anguilla
# Latvia
# Panama
# Ukraine
# Macao, China
# Antigua and Barbuda
# Saint Lucia
# Cameroon
# Croatia
# Hong Kong, China
# British Caribbean Territories
# Malta
# Kazakhstan
# United States of America
# Norway
# Madagascar
# Georgia
# Thailand
# Cambodia
# Guyana
# Afghanistan
# Bangladesh
# Iraq
# Slovakia
# Costa Rica
# Ghana
# Algeria
# Côte d'Ivoire
# United Arab Emirates
# Albania
# Tajikistan
# Mongolia
# Eritrea
# Lao People's Democratic Republic
# Micronesia (Federated States of)
# Malawi
# Monaco
# Bhutan
# Canada
# Burundi
# Hungary
# United Republic of Tanzania
# Nauru
# Greece
# Germany
# Colombia
# France
# Andorra
# Austria
# Cyprus
# Finland
# Jordan
# Comoros
# Maldives
# Togo
# Luxembourg
# Bosnia and Herzegovina
# Central African Republic
# Myanmar
# Cabo Verde
# Bahamas
# Suriname
# Argentina
# French Polynesia
# Peru
# Kenya
# Sierra Leone
# Mozambique
# British Caribbean Territories - British Virgin Islands
# Republic of Moldova
# Ecuador
# Turkmenistan
# Mexico
# Uganda
# British Caribbean Territories - Cayman Islands
# Tonga
# Niue
# Venezuela, Bolivarian Republic of
# Saudi Arabia
# Solomon Islands
# Dominica
# Gambia (The)
# Italy
# Zimbabwe
# Fiji
# New Zealand
# El Salvador
# Malaysia
# Liberia
# Niger
# Mali
# Japan
# Lebanon
# Indonesia
# Jamaica
# Democratic Republic of the Congo
# Viet Nam
# Vanuatu
# Montenegro
# Guinea
# Mauritania
# Dominican Republic
# Honduras
# Lithuania
# Eswatini
# Israel
# Cuba
# Ethiopia
# Lesotho
# Iceland
# Australia
# Gabon
# Haiti
# Nigeria
# Portugal
# Romania
# Senegal
# Sudan
# Timor-Leste
# Botswana
# New Caledonia
# British Caribbean Territories - Turks and Caicos Islands
# Uruguay
# Samoa
# Nepal
# Denmark
# Barbados
# Belize
# Namibia
# Qatar
# Rwanda
# Serbia
# South Africa
# Yemen
# Mauritius
# Cook Islands
# Guinea-Bissau
# Belarus
# Slovenia
# China
# India
# Türkiye
# Tunisia
# Somalia
# Benin
# Oman
# Switzerland
# Russian Federation
# Congo
# Iran (Islamic Republic of)
# Trinidad and Tobago
# Syrian Arab Republic
# Angola
# Paraguay
# Sweden
# Spain
# Guatemala
# Armenia
# Belgium
# South Sudan
# Netherlands
# Estonia
# Philippines
# Bulgaria
# Kyrgyzstan
# United Kingdom of Great Britain and Northern Ireland
# Republic of Korea
# Libya (State of)
# Bahrain
#                                                 country  \
# 0                                      Papua New Guinea
# 1                                      Papua New Guinea
# 2                                             Singapore
# 3                                      Papua New Guinea
# 4                                             Singapore
# ...                                                 ...
# 1333  United Kingdom of Great Britain and Northern I...
# 1334                                  Republic of Korea
# 1335                                  Republic of Korea
# 1336                                   Libya (State of)
# 1337                                            Bahrain
#
#                                                   title  \
# 0                                             Not found
# 1                                             Not found
# 2                                             Not found
# 3                                             Not found
# 4                                             Not found
# ...                                                 ...
# 1333                                          Not found
# 1334  Analysis on Effectiveness of Impact Based Heat...
# 1335  Effects of heat waves on daily excess mortalit...
# 1336                                          Not found
# 1337                                          Not found
#
#                                                 authors  \
# 0                                             Not found
# 1                                             Not found
# 2                                             Not found
# 3                                             Not found
# 4                                             Not found
# ...                                                 ...
# 1333                                          Not found
# 1334                          Yeora Chae, Jongchul Park
# 1335  Dae-Geun Lee, Kyu Rang Kim, Jiyoung Kim, Baek-...
# 1336                                          Not found
# 1337                                          Not found
#
#                                                abstract
# 0                                             Not found
# 1                                             Not found
# 2                                             Not found
# 3                                             Not found
# 4                                             Not found
# ...                                                 ...
# 1333                                          Not found
# 1334  Many countries are operating a heatwave warnin...
# 1335  The aims of this study are to explore the "off...
# 1336                                          Not found
# 1337                                          Not found
#
# [1338 rows x 4 columns]

# %%
df_collector
# Out:
#                                                 country  \
# 0                                      Papua New Guinea
# 1                                      Papua New Guinea
# 2                                             Singapore
# 3                                      Papua New Guinea
# 4                                             Singapore
# ...                                                 ...
# 1333  United Kingdom of Great Britain and Northern I...
# 1334                                  Republic of Korea
# 1335                                  Republic of Korea
# 1336                                   Libya (State of)
# 1337                                            Bahrain
#
#                                                   title  \
# 0                                             Not found
# 1                                             Not found
# 2                                             Not found
# 3                                             Not found
# 4                                             Not found
# ...                                                 ...
# 1333                                          Not found
# 1334  Analysis on Effectiveness of Impact Based Heat...
# 1335  Effects of heat waves on daily excess mortalit...
# 1336                                          Not found
# 1337                                          Not found
#
#                                                 authors  \
# 0                                             Not found
# 1                                             Not found
# 2                                             Not found
# 3                                             Not found
# 4                                             Not found
# ...                                                 ...
# 1333                                          Not found
# 1334                          Yeora Chae, Jongchul Park
# 1335  Dae-Geun Lee, Kyu Rang Kim, Jiyoung Kim, Baek-...
# 1336                                          Not found
# 1337                                          Not found
#
#                                                abstract
# 0                                             Not found
# 1                                             Not found
# 2                                             Not found
# 3                                             Not found
# 4                                             Not found
# ...                                                 ...
# 1333                                          Not found
# 1334  Many countries are operating a heatwave warnin...
# 1335  The aims of this study are to explore the "off...
# 1336                                          Not found
# 1337                                          Not found
#
# [1338 rows x 4 columns]

# %%
country_variations = {
    "United States of America": ["USA", "United States", "U.S.", "U.S.A."],
    "United Kingdom of Great Britain and Northern Ireland": ["UK", "Britain", "Great Britain", "U.K.", "United Kingdom"],
    "United Arab Emirates": ["UAE", "U.A.E."],
    "Russian Federation": ["Russia"],
    "Republic of Korea": ["South Korea"],
    "Democratic People's Republic of Korea": ["North Korea"],
    "Bolivia (Plurinational State of)": ["Bolivia"],
    "Iran (Islamic Republic of)": ["Iran"],
    "Venezuela, Bolivarian Republic of": ["Venezuela"],
    "Taiwan, Province of China": ["Taiwan"],
    # ... add more as needed
}

# %%
country_variations
# Out:
# {'United States of America': ['USA', 'United States', 'U.S.', 'U.S.A.'],
#  'United Kingdom': ['UK', 'Britain', 'Great Britain', 'U.K.'],
#  'United Arab Emirates': ['UAE', 'U.A.E.'],
#  'Russian Federation': ['Russia'],
#  'Republic of Korea': ['South Korea'],
#  "Democratic People's Republic of Korea": ['North Korea'],
#  'Bolivia (Plurinational State of)': ['Bolivia'],
#  'Iran (Islamic Republic of)': ['Iran'],
#  'Venezuela, Bolivarian Republic of': ['Venezuela'],
#  'Taiwan, Province of China': ['Taiwan']}

# %%
# ... (Your previous code that populates df_collector)

# Step 1: Iterate through the df_collector dataframe
for index, row in df_collector.iterrows():
    # Step 2: Check if the country is a key in country_variations and its status is "Not found"
    if row["country"] in country_variations and row["title"] == "Not found":
        # Step 3: Use the alternative names to search for articles
        print(f"Searching for alternative names for {row['country']}")
        for variation in country_variations[row["country"]]:
            print(f"Trying variation: {variation}")
            keyword = f"(\"heatwave warning system\" OR \"heat health warning system\") AND \"{variation}\""
            pmids = search_pubmed(keyword)
            
            if pmids:
                xml_data = fetch_details(pmids)
                articles = extract_details_from_xml(xml_data)
                if articles:
                    # Step 4: Update the dataframe with the details of the found article
                    df_collector.at[index, "title"] = articles[0]["title"]
                    df_collector.at[index, "authors"] = articles[0]["authors"]
                    df_collector.at[index, "abstract"] = articles[0]["abstract"]
                    break  # Exit the loop once an article is found

# Step 5: If no articles are found after trying all variations, it will keep the "Not found" status in the dataframe

print(df_collector)
# Out:
# Searching for alternative names for Bolivia (Plurinational State of)
# Trying variation: Bolivia
# Searching for alternative names for Bolivia (Plurinational State of)
# Trying variation: Bolivia
# Searching for alternative names for Bolivia (Plurinational State of)
# Trying variation: Bolivia
# Searching for alternative names for Democratic People's Republic of Korea
# Trying variation: North Korea
# Searching for alternative names for Democratic People's Republic of Korea
# Trying variation: North Korea
# Searching for alternative names for Democratic People's Republic of Korea
# Trying variation: North Korea
# Searching for alternative names for United Arab Emirates
# Trying variation: UAE
# Trying variation: U.A.E.
# Searching for alternative names for United Arab Emirates
# Trying variation: UAE
# Trying variation: U.A.E.
# Searching for alternative names for United Arab Emirates
# Trying variation: UAE
# Trying variation: U.A.E.
# Searching for alternative names for United Arab Emirates
# Trying variation: UAE
# Trying variation: U.A.E.
# Searching for alternative names for United Arab Emirates
# Trying variation: UAE
# Trying variation: U.A.E.
# Searching for alternative names for United Arab Emirates
# Trying variation: UAE
# Trying variation: U.A.E.
# Searching for alternative names for Venezuela, Bolivarian Republic of
# Trying variation: Venezuela
# Searching for alternative names for Venezuela, Bolivarian Republic of
# Trying variation: Venezuela
# Searching for alternative names for Russian Federation
# Trying variation: Russia
# Searching for alternative names for Russian Federation
# Trying variation: Russia
# Searching for alternative names for Russian Federation
# Trying variation: Russia
# Searching for alternative names for Russian Federation
# Trying variation: Russia
# Searching for alternative names for United Kingdom of Great Britain and Northern Ireland
# Trying variation: UK
# Searching for alternative names for United Kingdom of Great Britain and Northern Ireland
# Trying variation: UK
# Searching for alternative names for United Kingdom of Great Britain and Northern Ireland
# Trying variation: UK
# Searching for alternative names for United Kingdom of Great Britain and Northern Ireland
# Trying variation: UK
#                                                 country  \
# 0                                      Papua New Guinea
# 1                                      Papua New Guinea
# 2                                             Singapore
# 3                                      Papua New Guinea
# 4                                             Singapore
# ...                                                 ...
# 1333  United Kingdom of Great Britain and Northern I...
# 1334                                  Republic of Korea
# 1335                                  Republic of Korea
# 1336                                   Libya (State of)
# 1337                                            Bahrain
#
#                                                   title  \
# 0                                             Not found
# 1                                             Not found
# 2                                             Not found
# 3                                             Not found
# 4                                             Not found
# ...                                                 ...
# 1333  Wet Bulb Globe Temperature: Indicating Extreme...
# 1334  Analysis on Effectiveness of Impact Based Heat...
# 1335  Effects of heat waves on daily excess mortalit...
# 1336                                          Not found
# 1337                                          Not found
#
#                                                 authors  \
# 0                                             Not found
# 1                                             Not found
# 2                                             Not found
# 3                                             Not found
# 4                                             Not found
# ...                                                 ...
# 1333  Chloe Brimicombe, Chun Hay Brian Lo, Florian P...
# 1334                          Yeora Chae, Jongchul Park
# 1335  Dae-Geun Lee, Kyu Rang Kim, Jiyoung Kim, Baek-...
# 1336                                          Not found
# 1337                                          Not found
#
#                                                abstract
# 0                                             Not found
# 1                                             Not found
# 2                                             Not found
# 3                                             Not found
# 4                                             Not found
# ...                                                 ...
# 1333  The Wet Bulb Globe Temperature (WBGT) is an in...
# 1334  Many countries are operating a heatwave warnin...
# 1335  The aims of this study are to explore the "off...
# 1336                                          Not found
# 1337                                          Not found
#
# [1338 rows x 4 columns]

# %%
# ... (Your previous code that populates df_collector)

# Step 1: Iterate through the df_collector dataframe
for index, row in df_collector.iterrows():
    # Step 2: Check if the country is a key in country_variations and its status is "Not found"
    if row["country"] in country_variations and row["title"] == "Not found":
        print(f"Trying to find alternative names for {row['country']}")
        # Step 3: Use the alternative names to search for articles
        for variation in country_variations[row["country"]]:
            print(f"Trying variation: {variation}")
            keyword = f"(\"heatwave warning system\" OR \"heat health warning system\") AND \"{variation}\""
            pmids = search_pubmed(keyword)
            
            if pmids:
                xml_data = fetch_details(pmids)
                articles = extract_details_from_xml(xml_data)
                if articles:
                    # Step 4: Update the dataframe with the details of the found article
                    df_collector.at[index, "title"] = articles[0]["title"]
                    df_collector.at[index, "authors"] = articles[0]["authors"]
                    df_collector.at[index, "abstract"] = articles[0]["abstract"]
                    break  # Exit the loop once an article is found

# Step 5: If no articles are found after trying all variations, it will keep the "Not found" status in the dataframe

print(df_collector)
# Out:
#                                                 country  \
# 0                                      Papua New Guinea
# 1                                      Papua New Guinea
# 2                                             Singapore
# 3                                      Papua New Guinea
# 4                                             Singapore
# ...                                                 ...
# 1333  United Kingdom of Great Britain and Northern I...
# 1334                                  Republic of Korea
# 1335                                  Republic of Korea
# 1336                                   Libya (State of)
# 1337                                            Bahrain
#
#                                                   title  \
# 0                                             Not found
# 1                                             Not found
# 2                                             Not found
# 3                                             Not found
# 4                                             Not found
# ...                                                 ...
# 1333                                          Not found
# 1334  Analysis on Effectiveness of Impact Based Heat...
# 1335  Effects of heat waves on daily excess mortalit...
# 1336                                          Not found
# 1337                                          Not found
#
#                                                 authors  \
# 0                                             Not found
# 1                                             Not found
# 2                                             Not found
# 3                                             Not found
# 4                                             Not found
# ...                                                 ...
# 1333                                          Not found
# 1334                          Yeora Chae, Jongchul Park
# 1335  Dae-Geun Lee, Kyu Rang Kim, Jiyoung Kim, Baek-...
# 1336                                          Not found
# 1337                                          Not found
#
#                                                abstract
# 0                                             Not found
# 1                                             Not found
# 2                                             Not found
# 3                                             Not found
# 4                                             Not found
# ...                                                 ...
# 1333                                          Not found
# 1334  Many countries are operating a heatwave warnin...
# 1335  The aims of this study are to explore the "off...
# 1336                                          Not found
# 1337                                          Not found
#
# [1338 rows x 4 columns]

# %%
# Save as CSV
df_collector.to_csv("pubmed.csv", index=False)

# Save as pickle
df_collector.to_pickle("pubmed.pkl")
